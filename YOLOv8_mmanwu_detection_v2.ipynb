# %% [markdown]
# ## Mmanwu Object Detection With YOLOv8
#
# <a href='https://yolov8.com/'>YOLOv8</a> (You only look once) is a computer vision model developed by Ultralytics. It supports object detection, classification and segmentation tasks. YOLOv8 model is applied to detect masquerades from images. The training images were annotated with <a href='https://www.cvat.ai/'>CVAT</a> compouter vision annotation tool.
#
# <img src="./pix/IMG_4948.jpg" alt="image" width="45%" height="auto"> <img src="./pix/IMG_5074.jpg" alt="image" width="45%" height="auto">
#
# #### Objective
# To apply a pretrained computer vision model in an object detection task. The YOLOv8 object-detetction model is used to
# identify masquerades from pictures. An image of a masquerade is usually not taken in isolation. A typical picture will contain a mixture of its followers, instrumentalists, dancers, and crowd.
#
# #### Data
# 273 images taken by <a href='https://www.ositaphotography.com/'>Osita Photography</a>
#
# <img src="./pix/train_batch0.jpg" alt="image" width="45%" height="auto"> <img src="./pix/train_batch1.jpg" alt="image" width="45%" height="auto">
# <p>
# <img src="./pix/IMG_5133.jpg" alt="image" width="91%" height="auto">

# %%
# !python train.py
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
# !python predict.py
# Out:
# 0: 640x352 (no detections), 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 36.6ms
# Speed: 0.6ms preprocess, 36.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 35.7ms
# Speed: 0.6ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 34.9ms
# Speed: 0.6ms preprocess, 34.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 34.4ms
# Speed: 0.5ms preprocess, 34.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 32.7ms
# Speed: 0.5ms preprocess, 32.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 34.3ms
# Speed: 0.6ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# ...
